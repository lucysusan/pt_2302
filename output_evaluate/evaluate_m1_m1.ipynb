# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import pyfolio as pf
import warnings

warnings.filterwarnings('ignore')
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']

index_sid = '000906.SH'
data_folder = '../output/0301/-1month_1month/'
file_list = os.listdir(data_folder)

print(file_pkl := [f for f in file_list if not f.endswith('.csv')])
# Out:
# ['2017-01-01_2017-01-01', '2017-01-01_2017-06-30_-1month_1month_ret_index', '2017-02-01_2017-02-01', '2017-03-01_2017-03-01', '2017-04-01_2017-04-01', '2017-05-01_2017-05-01', '2022-10-01_2023-01-02_-1month_1month_ret_index', '2022-11-01_2022-11-01', '2022-12-01_2022-12-01', 'trading_log_file.log']

# %%
file = '2022-10-01_2023-01-02_-1month_1month_ret_index'

print('\n\n--------------------------------------------------------------------------\n',file)
data = pd.read_pickle(data_folder + file)
data.plot(figsize=(30,18))
plt.title('return')
plt.show()
pf.create_full_tear_sheet(data['ret'], benchmark_rets=data[index_sid])
# Out:
# --------------------------------------------------------------------------
#  2022-10-01_2023-01-02_-1month_1month_ret_index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2022-11-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-12-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>2</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-16.375%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-2.937%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.691%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.87</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-2.28</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import pyfolio as pf
import warnings

warnings.filterwarnings('ignore')
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']

index_sid = '000906.SH'
data_folder = '../OUT_DATA/'
file_list = os.listdir(data_folder)

print(file_pkl := [f for f in file_list if not f.endswith('.csv')])
# Out:
# c:\users\lucysusan\appdata\local\programs\python\python38\lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# ['2016-01-01_2022-11-29_-1year_2quarter_ret_index', '2016-07-01_2022-11-29_-2quarter_1year_ret_index', '2016-07-01_2022-11-29_-2quarter_2quarter_ret_index', '2016-10-01_2022-11-29_-1quarter_1month_ret_index', '2016-10-01_2022-11-29_-1quarter_1quarter_ret_index', '2016-12-01_2022-11-29_-1month_1month_ret_index']

# %%
file = '2016-10-01_2022-11-29_-1quarter_1quarter_ret_index'

print('\n\n--------------------------------------------------------------------------\n', file)
data = pd.read_pickle(data_folder + file)
data.plot(figsize=(30, 18))
plt.title('return')
plt.show()
pf.create_full_tear_sheet(data['ret'], benchmark_rets=data[index_sid])
# Out:
# --------------------------------------------------------------------------
#  2016-10-01_2022-11-29_-1quarter_1quarter_ret_index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-09-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>65</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-20.774%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-71.959%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>19.049%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.13</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.26</td>
#     </tr>
#     <tr>
# ...

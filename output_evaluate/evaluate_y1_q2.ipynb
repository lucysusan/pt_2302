# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import pyfolio as pf
import warnings

warnings.filterwarnings('ignore')
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']

index_sid = '000906.SH'
data_folder = '../OUT_DATA/0302/'
file_list = os.listdir(data_folder)

print(file_pkl := [f for f in file_list if f.endswith('ret_index')])
file = [f for f in file_pkl if '1year_2quarter' in f][0]
# Out:
# c:\users\lucysusan\appdata\local\programs\python\python38\lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(
# ['2017-01-01_2023-01-02_-1year_1year_ret_index', '2017-01-01_2023-01-02_-1year_2quarter_ret_index', '2017-07-01_2023-01-02_-2quarter_1year_ret_index', '2017-07-01_2023-01-02_-2quarter_2quarter_ret_index', '2017-10-01_2023-01-02_-1quarter_1month_ret_index', '2017-10-01_2023-01-02_-1quarter_1quarter_ret_index', '2017-12-01_2023-01-02_-1month_1month_ret_index']

# %%
print('\n\n--------------------------------------------------------------------------\n', file)
data = pd.read_pickle(data_folder + file)
data.plot(figsize=(30, 18))
plt.title('return')
plt.show()
pf.create_full_tear_sheet(data['ret'], benchmark_rets=data[index_sid])
# Out:
# --------------------------------------------------------------------------
#  2017-01-01_2023-01-02_-1year_2quarter_ret_index
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-12-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>57</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-2.944%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-13.317%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>6.214%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.10</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-28.164%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.62</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.16</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.47</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.03</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.794%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.07</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-1.42%</td>
#       <td>1.22%</td>
#     </tr>
#     <tr>
#       <th>Covid</th>
#       <td>-0.01%</td>
#       <td>-1.64%</td>
#       <td>1.58%</td>
#     </tr>
#   </tbody>
# </table>
